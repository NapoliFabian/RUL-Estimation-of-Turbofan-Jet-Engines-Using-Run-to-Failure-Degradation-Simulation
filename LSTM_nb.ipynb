# %%
import numpy as np
data = np.load("rul_data.npz")
X_train_seq = data['X_train']
y_train_seq = data['y_train']
X_test_seq = data['X_test']
y_test_seq = data['y_test']

# %%
X_train_seq.shape, y_train_seq.shape, X_test_seq.shape, y_test_seq.shape
# Out:
# ((17731, 30, 13), (17731,), (100, 30, 13), (100,))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
from sklearn.metrics import r2_score

def calculate_errors(y_true, y_pred):
    # Mean Squared Error
    mse = mean_squared_error(y_true, y_pred)
    # Root Mean Squared Error
    rmse = np.sqrt(mse)
    # Mean Absolute Error
    mae = mean_absolute_error(y_true, y_pred)
    # Root Relative Squared Error
    rrse = np.sqrt(np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    # Relative Absolute Error
    rae = np.sum(np.abs(y_true - y_pred)) / np.sum(np.abs(y_true - np.mean(y_true)))
    # R-squared
    r2 = r2_score(y_true, y_pred)
    # Correlation Coefficient
    cc = np.corrcoef(y_true, y_pred)[0, 1]

    return {
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "RRSE": rrse,
        "RAE": rae,
        "R2": r2,
        "CC": cc
    }

# %%
from tensorflow.keras.layers import LSTM, Dense, Dropout , BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
"""    LSTM(16, input_shape=X_train_seq.shape[1:]),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dense(1)"""
model = Sequential([

LSTM(64, input_shape=X_train_seq.shape[1:]),
Dense(32, activation='relu'),
BatchNormalization(),
Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model.summary()
# Out:
# c:\Users\thema\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_62 (LSTM)                  │ (None, 64)             │        19,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 32)             │           128 │
# ...

# %%
"""from sklearn.metrics import r2_score

for epoch_count in range(1, 31):
    print(f"\nTraining con {epoch_count} epoche")
    
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train_seq, y_train_seq, epochs=epoch_count, batch_size=32, verbose=0)

    y_pred = model.predict(X_test_seq)
    r2 = r2_score(y_test_seq, y_pred)

    print(f"Epochs: {epoch_count}, R2 Score: {r2:.4f}")"""
# Out:
# 'from sklearn.metrics import r2_score\n\nfor epoch_count in range(1, 31):\n    print(f"\nTraining con {epoch_count} epoche")\n\n    # Ricrea il modello da zero (se necessario, altrimenti sovrascrive il training precedente)\n    model.compile(optimizer=Adam(learning_rate=0.001), loss=\'mse\')\n\n    history = model.fit(X_train_seq, y_train_seq, epochs=epoch_count, batch_size=32, verbose=0)\n\n    y_pred = model.predict(X_test_seq)\n    r2 = r2_score(y_test_seq, y_pred)\n\n    print(f"Epochs: {epoch_count}, R2 Score: {r2:.4f}")'

# %%
history = model.fit(
    X_train_seq,
    y_train_seq,
    epochs=10,
    batch_size=32,
)

#10
# Out:
# Epoch 1/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 7219.5015
# Epoch 2/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3073.2568
# Epoch 3/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 775.2729
# Epoch 4/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 513.8522
# Epoch 5/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 510.6087
# Epoch 6/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 492.8912
# Epoch 7/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 493.9234
# Epoch 8/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 478.6596
# Epoch 9/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 496.4713
# Epoch 10/10
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 480.9434

# %%
y_pred = model.predict(X_test_seq)
predictions_test = model.predict(X_test_seq).flatten()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
errors_test = calculate_errors(y_test_seq, predictions_test)
print("Errore Test")
for key, value in errors_test.items():
    print(f"{key}: {value}")
# Out:
# Errore Test
# MSE: 214.24404849156406
# RMSE: 14.637077867237165
# MAE: 11.009378023147583
# RRSE: 0.35222859556724434
# RAE: 0.29943476857491413
# R2: 0.8759350164647266
# CC: 0.9394618364799522
